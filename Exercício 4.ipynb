# %% [markdown]
# ## Exercício 4

# %% [markdown]
# **Importando bibliotecas**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Importando dados como um dataframe**

# %%
dataframe = pd.read_fwf('data.txt',header=None,
names=["Router1", "Router2", "Router3", "Router4","Router5","Router6","Router7", "Room"])

# %% [markdown]
# ---

# %% [markdown]
# ### Roteador 1

# %%
ex3Router1 = dataframe.loc[:, ['Router1', 'Room']]
ex3Router1.boxplot(column='Router1', by='Room')

# %% [markdown]
# ---

# %% [markdown]
# ### Roteador 2

# %%
ex3Router2 = dataframe.loc[:, ['Router2', 'Room']]
ex3Router2.boxplot(column='Router2', by='Room')

# %% [markdown]
# ---

# %% [markdown]
# ### Roteador 3

# %%
ex3Router3 = dataframe.loc[:, ['Router3', 'Room']]
ex3Router3.boxplot(column='Router3', by='Room')

# %% [markdown]
# ---

# %% [markdown]
# ### Roteador 4

# %%
ex3Router4 = dataframe.loc[:, ['Router4', 'Room']]
ex3Router4.boxplot(column='Router4', by='Room')

# %% [markdown]
# ---

# %% [markdown]
# ### Roteador 5

# %%
ex3Router5 = dataframe.loc[:, ['Router5', 'Room']]
ex3Router5.boxplot(column='Router5', by='Room')

# %% [markdown]
# ---

# %% [markdown]
# ### Roteador 6

# %%
ex3Router6 = dataframe.loc[:, ['Router6', 'Room']]
ex3Router6.boxplot(column='Router6', by='Room')

# %% [markdown]
# ---

# %% [markdown]
# ### Roteador 7

# %%
ex3Router7 = dataframe.loc[:, ['Router7', 'Room']]
ex3Router7.boxplot(column='Router7', by='Room')

# %% [markdown]
# ---

# %% [markdown]
# ### Resposta

# %%
dataframe.var() # calculando a variância para comprovar o resultado
# Out:
# Router1    128.180360
# Router2     11.680588
# Router3     28.261835
# Router4    131.606381
# Router5     82.902711
# Router6     42.467009
# Router7     42.507952
# Room         1.250625
# dtype: float64

# %% [markdown]
# Observando os gráficos podemos concluir que o roteador 2 é o que menos varia, portanto utilizando o critério de menor variabilidade entre as salas esse roteador é o menos relevante para o algoritmo de detecção.
